# %%
import pandas as pd

# %%
result_df=pd.read_csv('results.csv')
result_df
# Out:
#            date  Daily New Tests  Total Tests  Daily new deaths  Total deaths  \
# 0    2020-03-08              9.0        120.0               0.0           0.0
# 1    2020-03-09              7.0        127.0               0.0           0.0
# 2    2020-03-10             10.0        137.0               0.0           0.0
# 3    2020-03-11             10.0        147.0               0.0           0.0
# 4    2020-03-12             16.0        163.0               0.0           0.0
# ..          ...              ...          ...               ...           ...
# 321  2020-04-06            468.0       3349.0               3.0          12.0
# 322  2020-04-07            792.0       4141.0               5.0          17.0
# 323  2020-04-08            981.0       5122.0               3.0          20.0
# 324  2020-04-09            905.0       6175.0               1.0          21.0
# 325  2020-04-10           1148.0       7359.0               6.0          27.0
#
# ...

# %%
result_df['Daily New Tests'].plot()
# Out:
# <AxesSubplot:>

# %%
result_df.set_index('date',inplace=True)
result_df
#setting index as a date
# Out:
#             Daily New Tests  Total Tests  Daily new deaths  Total deaths  \
# date
# 2020-03-08              9.0        120.0               0.0           0.0
# 2020-03-09              7.0        127.0               0.0           0.0
# 2020-03-10             10.0        137.0               0.0           0.0
# 2020-03-11             10.0        147.0               0.0           0.0
# 2020-03-12             16.0        163.0               0.0           0.0
# ...                     ...          ...               ...           ...
# 2020-04-06            468.0       3349.0               3.0          12.0
# 2020-04-07            792.0       4141.0               5.0          17.0
# 2020-04-08            981.0       5122.0               3.0          20.0
# 2020-04-09            905.0       6175.0               1.0          21.0
# 2020-04-10           1148.0       7359.0               6.0          27.0
#
#             deaths_per_million  Tests_per_million  Daily new recovered  \
# date
# ...

# %%
result_df.loc['2020-04-08']
# Out:
#             Daily New Tests  Total Tests  Daily new deaths  Total deaths  \
# date
# 2020-04-08            981.0       5122.0               3.0          20.0
# 2020-04-08            981.0       5122.0               3.0          20.0
# 2020-04-08            981.0       5122.0               3.0          20.0
# 2020-04-08            981.0       5122.0               3.0          20.0
# 2020-04-08            981.0       5122.0               3.0          20.0
#
#             deaths_per_million  Tests_per_million  Daily new recovered  \
# date
# 2020-04-08            0.121441          31.100973                  0.0
# 2020-04-08            0.121441          31.100973                  0.0
# 2020-04-08            0.121441          31.100973                  0.0
# 2020-04-08            0.121441          31.100973                  0.0
# 2020-04-08            0.121441          31.100973                  0.0
#
#             Total recovered
# date
# 2020-04-08             33.0
# ...

# %%
result_df['Total Tests']
# Out:
# date
# 2020-03-08     120.0
# 2020-03-09     127.0
# 2020-03-10     137.0
# 2020-03-11     147.0
# 2020-03-12     163.0
#                ...
# 2020-04-06    3349.0
# 2020-04-07    4141.0
# 2020-04-08    5122.0
# 2020-04-09    6175.0
# 2020-04-10    7359.0
# Name: Total Tests, Length: 326, dtype: float64

# %%
result_df['Total Tests'].plot()
result_df['Daily New Tests'].plot();

# %%
result_df['Total deaths'].plot()
result_df['Daily New Tests'].plot();

# %%
result_df['Daily new recovered'].plot(title='New Cases')
# Out:
# <AxesSubplot:title={'center':'New Cases'}, xlabel='date'>

# %%
result_df['Total deaths'].plot(kind='bar');
