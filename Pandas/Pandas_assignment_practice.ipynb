# %%
import pandas as pd

# %%
countries_df = pd.read_csv('countries.csv')
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %%
num_countries=countries_df.shape

# %%
print('There are {} countries in the dataset'.format(num_countries[0]))
# Out:
# There are 210 countries in the dataset

# %%
continents=countries_df.continent.unique()
continents
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
grouped_continents=countries_df.groupby('continent')['population'].sum()
grouped_continents
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %%
Total_population=countries_df['population'].sum()
Total_population
# Out:
# 7757980095.0

# %%
print("The total population  is {}.".format(int(Total_population)));
# Out:
# The total population  is 7757980095.

# %%
overall_life_expectancy= countries_df.life_expectancy.sum()/ countries_df.shape[0]
print(countries_df.shape[0])
overall_life_expectancy
# Out:
# 210
# 72.47942857142857

# %%
most_populous_df=countries_df.sort_values(by='population',ascending=False)
most_populous_df
# Out:
#                             location      continent    population  \
# 41                             China           Asia  1.439324e+09
# 90                             India           Asia  1.380004e+09
# 199                    United States  North America  3.310026e+08
# 91                         Indonesia           Asia  2.735236e+08
# 145                         Pakistan           Asia  2.208923e+08
# ..                               ...            ...           ...
# 24   Bonaire Sint Eustatius and Saba  North America  2.622100e+04
# 5                           Anguilla  North America  1.500200e+04
# 130                       Montserrat  North America  4.999000e+03
# 65                  Falkland Islands  South America  3.483000e+03
# 203                          Vatican         Europe  8.090000e+02
#
#      life_expectancy  hospital_beds_per_thousand  gdp_per_capita
# 41             76.91                        4.34       15308.712
# ...

# %%
Total_life_expectancy=(countries_df.life_expectancy*countries_df.population).sum()
overall_life_expectancy =Total_life_expectancy /countries_df.population.sum()
overall_life_expectancy
# Out:
# 72.72165193409664

# %%
countries_df['gdp']= (countries_df.gdp_per_capita*countries_df.population).sum()/countries_df.population.sum()
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita          gdp
# 0                          0.50        1803.987  15151.58101
# 1                          2.89       11803.431  15151.58101
# 2                          1.90       13913.839  15151.58101
# ...

# %%
population_greater_than_100_million= countries_df[countries_df.population >100e6]
population_greater_than_100_million
# Out:
#           location      continent    population  life_expectancy  \
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 58           Egypt         Africa  1.023344e+08            71.99
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 90           India           Asia  1.380004e+09            69.66
# 91       Indonesia           Asia  2.735236e+08            71.72
# 99           Japan           Asia  1.264765e+08            84.63
# 125         Mexico  North America  1.289328e+08            75.05
# 141        Nigeria         Africa  2.061396e+08            54.69
# 145       Pakistan           Asia  2.208923e+08            67.27
# 151    Philippines           Asia  1.095811e+08            71.23
# 157         Russia         Europe  1.459345e+08            72.58
# ...

# %%
ten_countries_with_lowest_GDP=population_greater_than_100_million.sort_values(by='gdp_per_capita',ascending=True).head(10)
ten_countries_with_lowest_GDP
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita          gdp
# 63                         0.30        1729.927  15151.58101
# 15                         0.80        3523.984  15151.58101
# 145                        0.60        5034.708  15151.58101
# ...

# %%
country_counts_df=countries_df.groupby('continent')['location'].count()
country_counts_df
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %%
continent_populations_df=countries_df.groupby('continent')['population'].sum()
continent_populations_df
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %%
covid_data_df = pd.read_csv('covid-countries-data.csv')
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %%
total_tests_missing=covid_data_df[covid_data_df.total_tests.isna()].shape[0]
total_tests_missing
# .isna is from finding null value
# Out:
# 122

# %%
print("The data for total tests is missing for {} countries.".format(int(total_tests_missing)))
# Out:
# The data for total tests is missing for 122 countries.

# %%
combined_df=covid_data_df.merge(countries_df,on="location")
combined_df
# Out:
#            location  total_cases  total_deaths  total_tests continent  \
# 0       Afghanistan      38243.0        1409.0          NaN      Asia
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
combined_df['tests_per_million']= combined_df.total_tests*1e6 /combined_df.population
combined_df['cases_per_million']= combined_df.total_cases*1e6 /combined_df.population
combined_df['deaths_per_million']= combined_df.total_deaths*1e6 /combined_df.population
combined_df
# Out:
#            location  total_cases  total_deaths  total_tests continent  \
# 0       Afghanistan      38243.0        1409.0          NaN      Asia
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
highest_tests_df=combined_df.sort_values(by='tests_per_million',ascending=False).head(10)
highest_cases_df=combined_df.sort_values(by='cases_per_million',ascending=False).head(10)
highest_deaths_df=combined_df.sort_values(by='deaths_per_million',ascending=False).head(10)
highest_tests_df
# Out:
#                  location  total_cases  total_deaths  total_tests  \
# 197  United Arab Emirates      71540.0         387.0    7177430.0
# 14                Bahrain      52440.0         190.0    1118837.0
# 115            Luxembourg       7928.0         124.0     385820.0
# 122                 Malta       1931.0          13.0     188539.0
# 53                Denmark      17195.0         626.0    2447911.0
# 96                 Israel     122539.0         969.0    2353984.0
# 89                Iceland       2121.0          10.0      88829.0
# 157                Russia    1005000.0       17414.0   37176827.0
# 199         United States    6114406.0      185744.0   83898416.0
# 10              Australia      25923.0         663.0    6255797.0
#
#          continent   population  life_expectancy  hospital_beds_per_thousand  \
# 197           Asia    9890400.0            77.97                       1.200
# 14            Asia    1701583.0            77.29                       2.000
# ...

# %%
highest_cases_df
# Out:
#           location  total_cases  total_deaths  total_tests      continent  \
# 155          Qatar     119206.0         199.0     634745.0           Asia
# 14         Bahrain      52440.0         190.0    1118837.0           Asia
# 147         Panama      94084.0        2030.0     336345.0  North America
# 40           Chile     414739.0       11344.0    2458762.0  South America
# 162     San Marino        735.0          42.0          NaN         Europe
# 9            Aruba       2211.0          12.0          NaN  North America
# 105         Kuwait      86478.0         535.0     621616.0           Asia
# 150           Peru     663437.0       29259.0     584232.0  South America
# 27          Brazil    3997865.0      123780.0    4797948.0  South America
# 199  United States    6114406.0      185744.0   83898416.0  North America
#
#       population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
highest_deaths_df
# Out:
#            location  total_cases  total_deaths  total_tests      continent  \
# 162      San Marino        735.0          42.0          NaN         Europe
# 150            Peru     663437.0       29259.0     584232.0  South America
# 18          Belgium      85817.0        9898.0    2281853.0         Europe
# 3           Andorra       1199.0          53.0          NaN         Europe
# 177           Spain     479554.0       29194.0    6416533.0         Europe
# 198  United Kingdom     338676.0       41514.0   13447568.0         Europe
# 40            Chile     414739.0       11344.0    2458762.0  South America
# 97            Italy     271515.0       35497.0    5214766.0         Europe
# 27           Brazil    3997865.0      123780.0    4797948.0  South America
# 182          Sweden      84532.0        5820.0          NaN         Europe
#
#       population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
highest_test_and_case= (highest_cases_df.merge(highest_tests_df,on="location")).shape[0]
highest_test_and_case
# Out:
# 2

# %%
 population_10_million =combined_df[combined_df.population >10e6]
population_10_million
# Out:
#         location  total_cases  total_deaths  total_tests      continent  \
# 0    Afghanistan      38243.0        1409.0          NaN           Asia
# 2        Algeria      45158.0        1525.0          NaN         Africa
# 4         Angola       2729.0         109.0          NaN         Africa
# 7      Argentina     428226.0        8971.0    1118923.0  South America
# 10     Australia      25923.0         663.0    6255797.0        Oceania
# ..           ...          ...           ...          ...            ...
# 204    Venezuela      48883.0         398.0          NaN  South America
# 205      Vietnam       1046.0          35.0     261004.0           Asia
# 207        Yemen       1976.0         571.0          NaN           Asia
# 208       Zambia      12415.0         292.0          NaN         Africa
# 209     Zimbabwe       6638.0         206.0      97272.0         Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %%
lowest_GDP=population_10_million.sort_values(by='gdp_per_capita',ascending=True).head(20)
lowest_hospital_beds=population_10_million.sort_values(by='hospital_beds_per_thousand',ascending=True).head(20)
lowest_hospital_beds_and_GDP=lowest_GDP.merge(lowest_hospital_beds,on="location").shape[0]
lowest_hospital_beds_and_GDP
# Out:
# 14
