# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.4.4

# %%
pd.show_versions()
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : ca60aab7340d9989d9428e11a51467658190bb6b
# python           : 3.9.13.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.22621
# machine          : AMD64
# processor        : Intel64 Family 6 Model 126 Stepping 5, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.4.4
# numpy            : 1.21.5
# pytz             : 2022.1
# dateutil         : 2.8.2
# setuptools       : 63.4.1
# pip              : 22.2.2
# Cython           : 0.29.32
# pytest           : 7.1.2
# hypothesis       : None
# sphinx           : 5.0.2
# blosc            : None
# feather          : None
# xlsxwriter       : 3.0.3
# lxml.etree       : 4.9.1
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.3
# IPython          : 7.31.1
# pandas_datareader: None
# bs4              : 4.11.1
# bottleneck       : 1.3.5
# brotli           :
# fastparquet      : None
# fsspec           : 2022.7.1
# gcsfs            : None
# markupsafe       : 2.0.1
# matplotlib       : 3.5.2
# numba            : 0.55.1
# numexpr          : 2.8.3
# odfpy            : None
# openpyxl         : 3.0.10
# pandas_gbq       : None
# pyarrow          : None
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.9.1
# snappy           :
# sqlalchemy       : 1.4.39
# tables           : 3.6.1
# tabulate         : 0.8.10
# xarray           : 0.20.1
# xlrd             : 2.0.1
# xlwt             : None
# zstandard        : 0.19.0

# %%
import numpy as np

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(data,index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df.iloc[:3]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df.loc[:,['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df.loc[df.index[[3,4,8]],['animal','age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
df.iloc[3:]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df[df['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df[(df['animal']=='cat') & (df['age']<3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
#df[(df['age']>= 2) & (df['age']<=4)]
df[df['age'].between(2,4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
df.at['f','age']=1.5
df['age']
# Out:
# a    2.5
# b    3.0
# c    0.5
# d    NaN
# e    5.0
# f    1.5
# g    4.5
# h    NaN
# i    7.0
# j    3.0
# Name: age, dtype: float64

# %%
df['visits'].sum()
# Out:
# 19

# %%
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %%
df["K"]=np.arange(10)

df=df.drop('K',axis=1)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df['animal'].value_counts()
# Out:
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.sort_values(['age','visits'],ascending=[False,True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=labels)

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df['priority']= df['priority'].map({'yes':True,'no':False})
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  2.0       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %%
df['animal']=df['animal'].replace('snake','python')
df
# Out:
#    animal  age  visits  priority
# a     cat  2.5       1      True
# b     cat  3.0       3      True
# c  python  0.5       2     False
# d     dog  NaN       3      True
# e     dog  5.0       2     False
# f     cat  2.0       3     False
# g  python  4.5       1     False
# h     cat  NaN       1      True
# i     dog  7.0       2     False
# j     dog  3.0       1     False

# %%
df.pivot_table(index='animal',columns='visits',values='age',aggfunc='mean')
# Out:
# visits    1    2    3
# animal
# cat     2.5  NaN  2.5
# dog     3.0  6.0  NaN
# python  4.5  0.5  NaN

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})

# %%
df
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   5
# 8   6
# 9   7
# 10  7

# %%
df.loc[df['A'].shift() != df['A']]
# Out:
#    A
# 0  1
# 1  2
# 3  3
# 4  4
# 5  5
# 8  6
# 9  7

# %%
df = pd.DataFrame(np.random.random(size=(5, 3)))
df
# Out:
#           0         1         2
# 0  0.437810  0.578098  0.394930
# 1  0.381479  0.540793  0.927192
# 2  0.851256  0.132522  0.593723
# 3  0.014779  0.477701  0.748475
# 4  0.676849  0.289198  0.464145

# %%
df.sub(df.mean(axis=1),axis=0)
# Out:
#           0         1         2
# 0 -0.032469  0.107819 -0.075349
# 1 -0.235009 -0.075695  0.310704
# 2  0.325422 -0.393311  0.067889
# 3 -0.398873  0.064049  0.334824
# 4  0.200118 -0.187533 -0.012585

# %%
df.sub(df.mean(axis=1), axis=0)
# Out:
#           0         1         2
# 0 -0.032469  0.107819 -0.075349
# 1 -0.235009 -0.075695  0.310704
# 2  0.325422 -0.393311  0.067889
# 3 -0.398873  0.064049  0.334824
# 4  0.200118 -0.187533 -0.012585

# %%
df = pd.DataFrame(np.random.random(size=(5, 10)), columns=list('abcdefghij'))

# %%
df
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.965488  0.812571  0.211290  0.636867  0.432011  0.020962  0.250986
# 1  0.332482  0.862041  0.059978  0.478405  0.769738  0.097188  0.869109
# 2  0.942494  0.547670  0.868766  0.767509  0.897848  0.811144  0.324484
# 3  0.815661  0.094163  0.008950  0.062838  0.884252  0.758989  0.829829
# 4  0.407146  0.423070  0.411947  0.925419  0.107715  0.585859  0.986743
#
#           h         i         j
# 0  0.047526  0.394978  0.830000
# 1  0.615831  0.123580  0.095176
# 2  0.312969  0.988319  0.391957
# 3  0.270851  0.365447  0.576175
# 4  0.720568  0.170078  0.904212

# %%
 df.sum(axis=0).sort_values(ascending=True).index[0]
df.sum(axis=0).idxmin()

# both are right
# Out:
# 'c'

# %%
df = pd.DataFrame(np.random.randint(0, 2, size=(10, 3)))
df
# Out:
#    0  1  2
# 0  0  1  1
# 1  0  0  0
# 2  1  1  1
# 3  0  0  0
# 4  1  1  1
# 5  1  1  0
# 6  0  0  0
# 7  0  0  1
# 8  0  0  0
# 9  0  1  0

# %%
len(df.drop_duplicates(keep=False))
# Out:
# 4

# %%
nan = np.nan

data = [[0.04,  nan,  nan, 0.25,  nan, 0.43, 0.71, 0.51,  nan,  nan],
        [ nan,  nan,  nan, 0.04, 0.76,  nan,  nan, 0.67, 0.76, 0.16],
        [ nan,  nan, 0.5 ,  nan, 0.31, 0.4 ,  nan,  nan, 0.24, 0.01],
        [0.49,  nan,  nan, 0.62, 0.73, 0.26, 0.85,  nan,  nan,  nan],
        [ nan,  nan, 0.41,  nan, 0.05,  nan, 0.61,  nan, 0.48, 0.68]]

columns = list('abcdefghij')

df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#       a   b     c     d     e     f     g     h     i     j
# 0  0.04 NaN   NaN  0.25   NaN  0.43  0.71  0.51   NaN   NaN
# 1   NaN NaN   NaN  0.04  0.76   NaN   NaN  0.67  0.76  0.16
# 2   NaN NaN  0.50   NaN  0.31  0.40   NaN   NaN  0.24  0.01
# 3  0.49 NaN   NaN  0.62  0.73  0.26  0.85   NaN   NaN   NaN
# 4   NaN NaN  0.41   NaN  0.05   NaN  0.61   NaN  0.48  0.68

# %%
(df.isnull().cumsum(axis=1)==3).idxmax(axis=1)
# Out:
# 0    e
# 1    c
# 2    d
# 3    h
# 4    d
# dtype: object

# %%
df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'), 
                   'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})

# %%
df
# Out:
#    grps  vals
# 0     a    12
# 1     a   345
# 2     a     3
# 3     b     1
# 4     b    45
# 5     c    14
# 6     a     4
# 7     a    52
# 8     b    54
# 9     c    23
# 10    c   235
# 11    c    21
# 12    b    57
# 13    b     3
# 14    c    87

# %%
df.groupby('grps')['vals'].nlargest(3).sum(level=0)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_10148\1593056217.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   df.groupby('grps')['vals'].nlargest(3).sum(level=0)
# grps
# a    409
# b    156
# c    345
# Name: vals, dtype: int64

# %%
df = pd.DataFrame(np.random.RandomState(8765).randint(1, 101, size=(100, 2)), columns = ["A", "B"])
df
# Out:
#      A   B
# 0   46  29
# 1   75  22
# 2   49  63
# 3   33  43
# 4   71  75
# ..  ..  ..
# 95  60  87
# 96  57  40
# 97  86  19
# 98  50  56
# 99  97  94
#
# [100 rows x 2 columns]

# %%
df.groupby(pd.cut(df['A'], np.arange(0, 101, 10)))['B'].sum()
# Out:
# A
# (0, 10]      635
# (10, 20]     360
# (20, 30]     315
# (30, 40]     306
# (40, 50]     750
# (50, 60]     284
# (60, 70]     424
# (70, 80]     526
# (80, 90]     835
# (90, 100]    852
# Name: B, dtype: int32

# %%
df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})
df
# Out:
#    X
# 0  7
# 1  2
# 2  0
# 3  3
# 4  4
# 5  2
# 6  5
# 7  0
# 8  3
# 9  4

# %%
izero = np.r_[-1, (df == 0).values.nonzero()[0]]  # indices of zeros
idx = np.arange(len(df))
y = df['X'] != 0
df['Y'] = idx - izero[np.searchsorted(izero - 1, idx) - 1]
df
# Out:
#    X  Y
# 0  7  1
# 1  2  2
# 2  0  0
# 3  3  1
# 4  4  2
# 5  2  3
# 6  5  4
# 7  0  0
# 8  3  1
# 9  4  2

# %%
df = pd.DataFrame(np.random.RandomState(30).randint(1, 101, size=(8, 8)))
df
# Out:
#     0   1   2   3   4   5   6   7
# 0  38  38  46  46  13  24   3  54
# 1  18  47   4  42   8  66  50  46
# 2  62  36  19  19  77  17   7  63
# 3  28  47  46  65  63  12  16  24
# 4  14  51  34  56  29  59  92  79
# 5  58  76  96  45  38  76  58  40
# 6  10  34  48  40  37  23  41  26
# 7  55  70  91  27  79  92  20  31

# %%
df.unstack().sort_values()[-3:].index.tolist()
# Out:
# [(5, 7), (6, 4), (2, 5)]

# %%
df = pd.DataFrame({"vals": np.random.RandomState(31).randint(-30, 30, size=15), 
                   "grps": np.random.RandomState(31).choice(["A", "B"], 15)})

# %%
df
# Out:
#     vals grps
# 0    -12    A
# 1     -7    B
# 2    -14    A
# 3      4    A
# 4     -7    A
# 5     28    B
# 6     -2    A
# 7     -1    A
# 8      8    A
# 9     -2    B
# 10    28    A
# 11    12    A
# 12    16    A
# 13   -24    A
# 14   -12    A

# %%
 df = pd.DataFrame({'group': list('aabbabbbabab'),
                       'value': [1, 2, 3, np.nan, 2, 3, np.nan, 1, 7, 3, np.nan, 8]})
 df
# Out:
#    group  value
# 0      a    1.0
# 1      a    2.0
# 2      b    3.0
# 3      b    NaN
# 4      a    2.0
# 5      b    3.0
# 6      b    NaN
# 7      b    1.0
# 8      a    7.0
# 9      b    3.0
# 10     a    NaN
# 11     b    8.0

# %%
dti=pd.date_range(start='2015-01-01',end='2015-12-31',freq='B')
s=pd.Series(np.random.rand(len(dti)),index=dti)
s
# Out:
# 2015-01-01    0.284945
# 2015-01-02    0.983935
# 2015-01-05    0.132026
# 2015-01-06    0.507660
# 2015-01-07    0.078646
#                 ...
# 2015-12-25    0.003069
# 2015-12-28    0.585331
# 2015-12-29    0.504714
# 2015-12-30    0.873696
# 2015-12-31    0.956311
# Freq: B, Length: 261, dtype: float64

# %%
s[s.index.weekday==2].sum()
# Out:
# 29.967653041001327

# %%
s.resample('M').mean()
# Out:
# 2015-01-31    0.507888
# 2015-02-28    0.441171
# 2015-03-31    0.387146
# 2015-04-30    0.629871
# 2015-05-31    0.527205
# 2015-06-30    0.521229
# 2015-07-31    0.553993
# 2015-08-31    0.564260
# 2015-09-30    0.507992
# 2015-10-31    0.589361
# 2015-11-30    0.514298
# 2015-12-31    0.534710
# Freq: M, dtype: float64

# %%
s.resample('M').max().
# Out:
# 2015-01-31    0.983935
# 2015-02-28    0.979441
# 2015-03-31    0.974577
# 2015-04-30    0.956427
# 2015-05-31    0.967355
# 2015-06-30    0.926523
# 2015-07-31    0.973098
# 2015-08-31    0.990140
# 2015-09-30    0.983400
# 2015-10-31    0.988844
# 2015-11-30    0.994356
# 2015-12-31    0.993805
# Freq: M, dtype: float64

# %%
s.groupby(pd.Grouper(freq='4M')).idxmax()
# Out:
# 2015-01-31   2015-01-02
# 2015-05-31   2015-02-11
# 2015-09-30   2015-08-21
# 2016-01-31   2015-11-11
# Freq: 4M, dtype: datetime64[ns]

# %%
pd.date_range(start='2015-01-01',end='2016-12-31',freq='WOM-3THU')
# Out:
# DatetimeIndex(['2015-01-15', '2015-02-19', '2015-03-19', '2015-04-16',
#                '2015-05-21', '2015-06-18', '2015-07-16', '2015-08-20',
#                '2015-09-17', '2015-10-15', '2015-11-19', '2015-12-17',
#                '2016-01-21', '2016-02-18', '2016-03-17', '2016-04-21',
#                '2016-05-19', '2016-06-16', '2016-07-21', '2016-08-18',
#                '2016-09-15', '2016-10-20', '2016-11-17', '2016-12-15'],
#               dtype='datetime64[ns]', freq='WOM-3THU')

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
                               '12. Air France', '"Swiss Air"']})

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df['FlightNumber'] = df['FlightNumber'].interpolate().astype(int)
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
new=df.From_To.str.split('_',expand=True)
new.columns=['From','To']
new
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
new['From']=new['From'].str.capitalize()
new['To']=new['To'].str.capitalize()
new
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
df=df.drop('From_To',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13592\1029802442.py in <module>
# ----> 1 df=df.drop('From_To',axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['From_To'] not found in axis"

# %%
df=df.join(new)

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
df['Airline']=df['Airline'].str.extract('([a-zA-Z\s]+)', expand=False).str.strip()

# %%
df
# Out:
#    FlightNumber  RecentDelays          Airline      From         To
# 0         10045      [23, 47]              KLM    London      Paris
# 1         10055            []       Air France    Madrid      Milan
# 2         10065  [24, 43, 87]  British Airways    London  Stockholm
# 3         10075          [13]       Air France  Budapest      Paris
# 4         10085      [67, 32]        Swiss Air  Brussels     London

# %%
df['RecentDelays'].apply(pd.Series)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_13592\1587687658.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['RecentDelays'].apply(pd.Series)
#       0     1     2
# 0  23.0  47.0   NaN
# 1   NaN   NaN   NaN
# 2  24.0  43.0  87.0
# 3  13.0   NaN   NaN
# 4  67.0  32.0   NaN

# %%
delays = df['RecentDelays'].apply(pd.Series)

delays.columns = ['delay_{}'.format(n) for n in range(1, len(delays.columns)+1)]

df = df.drop('RecentDelays', axis=1).join(delays)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_13592\3601810322.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   delays = df['RecentDelays'].apply(pd.Series)

# %%
df
# Out:
#    FlightNumber          Airline      From         To  delay_1  delay_2  \
# 0         10045              KLM    London      Paris     23.0     47.0
# 1         10055       Air France    Madrid      Milan      NaN      NaN
# 2         10065  British Airways    London  Stockholm     24.0     43.0
# 3         10075       Air France  Budapest      Paris     13.0      NaN
# 4         10085        Swiss Air  Brussels     London     67.0     32.0
#
#    delay_3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN

# %%
letters = ['A', 'B', 'C']
numbers = list(range(10))
mi = pd.MultiIndex.from_product([letters, numbers])
s=pd.Series(np.random.rand(30),index=mi)
s
# Out:
# A  0    0.960232
#    1    0.918691
#    2    0.576127
#    3    0.988210
#    4    0.470423
#    5    0.006630
#    6    0.735322
#    7    0.432418
#    8    0.144146
#    9    0.348428
# B  0    0.829897
#    1    0.282366
#    2    0.944162
#    3    0.134112
#    4    0.618824
#    5    0.907780
#    6    0.683621
#    7    0.306063
#    8    0.761037
#    9    0.900983
# C  0    0.066655
#    1    0.155359
#    2    0.878826
#    3    0.579143
#    4    0.096842
#    5    0.156887
#    6    0.553475
#    7    0.170772
#    8    0.632365
#    9    0.638787
# dtype: float64

# %%
s.index.is_lexsorted()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_13592\2286347296.py:1: FutureWarning: MultiIndex.is_lexsorted is deprecated as a public function, users should use MultiIndex.is_monotonic_increasing instead.
#   s.index.is_lexsorted()
# True

# %%
s.index.lexsort_depth== s.index.nlevels
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_13592\649559849.py:1: FutureWarning: MultiIndex.is_lexsorted is deprecated as a public function, users should use MultiIndex.is_monotonic_increasing instead.
#   s.index.lexsort_depth== s.index.nlevels
# True

# %%
s.loc[:,[1,3,6]]
# Out:
# A  1    0.918691
#    3    0.988210
#    6    0.735322
# B  1    0.282366
#    3    0.134112
#    6    0.683621
# C  1    0.155359
#    3    0.579143
#    6    0.553475
# dtype: float64

# %%
s.loc[slice(None,'A'),slice(None,5)]
# Out:
# A  0    0.960232
#    1    0.918691
#    2    0.576127
#    3    0.988210
#    4    0.470423
#    5    0.006630
# dtype: float64

# %%
s.loc[pd.IndexSlice[:'B', 5:]]
# Out:
# A  5    0.006630
#    6    0.735322
#    7    0.432418
#    8    0.144146
#    9    0.348428
# B  5    0.907780
#    6    0.683621
#    7    0.306063
#    8    0.761037
#    9    0.900983
# dtype: float64

# %%
s.sum(level=0)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_13592\1970297740.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   s.sum(level=0)
# A    5.580627
# B    6.368845
# C    3.929111
# dtype: float64

# %%
s.unstack().sum(axis=0)
# Out:
# 0    1.856784
# 1    1.356416
# 2    2.399115
# 3    1.701465
# 4    1.186090
# 5    1.071297
# 6    1.972418
# 7    0.909253
# 8    1.537548
# 9    1.888198
# dtype: float64

# %%
new_s = s.swaplevel(0, 1)

if not new_s.index.is_lexsorted():
    new_s = new_s.sort_index()

new_s
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_13592\1882359081.py:3: FutureWarning: MultiIndex.is_lexsorted is deprecated as a public function, users should use MultiIndex.is_monotonic_increasing instead.
#   if not new_s.index.is_lexsorted():
# 0  A    0.960232
#    B    0.829897
#    C    0.066655
# 1  A    0.918691
#    B    0.282366
#    C    0.155359
# 2  A    0.576127
#    B    0.944162
#    C    0.878826
# 3  A    0.988210
#    B    0.134112
#    C    0.579143
# 4  A    0.470423
#    B    0.618824
#    C    0.096842
# 5  A    0.006630
#    B    0.907780
#    C    0.156887
# 6  A    0.735322
#    B    0.683621
#    C    0.553475
# 7  A    0.432418
#    B    0.306063
#    C    0.170772
# 8  A    0.144146
#    B    0.761037
#    C    0.632365
# 9  A    0.348428
#    B    0.900983
#    C    0.638787
# dtype: float64
