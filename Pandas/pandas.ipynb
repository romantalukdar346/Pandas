# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
# load the car.csv dataset
car_str = r'C:\Users\KIIT\OneDrive\Desktop\code 1\Data Analysis\Data Analysis using Python\car.csv'
car= pd.read_csv(car_str)
car.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
car.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
car.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
car.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
# convert pandas to numpy
car.columns.values
# Out:
# array(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size',
#        'Vehicle Style', 'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype=object)

# %%
car.describe(include='all')
# Out:
#              Make           Model          Year  Engine Fuel Type  \
# count       11914           11914  11914.000000             11911
# unique         48             915           NaN                10
# top     Chevrolet  Silverado 1500           NaN  regular unleaded
# freq         1123             156           NaN              7172
# mean          NaN             NaN   2010.384338               NaN
# std           NaN             NaN      7.579740               NaN
# min           NaN             NaN   1990.000000               NaN
# 25%           NaN             NaN   2007.000000               NaN
# 50%           NaN             NaN   2015.000000               NaN
# 75%           NaN             NaN   2016.000000               NaN
# max           NaN             NaN   2017.000000               NaN
#
#           Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# count   11845.00000      11884.000000             11914              11914
# ...

# %%
car.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Engine HP'}>,
#         <AxesSubplot:title={'center':'Engine Cylinders'}>],
#        [<AxesSubplot:title={'center':'Number of Doors'}>,
#         <AxesSubplot:title={'center':'highway MPG'}>,
#         <AxesSubplot:title={'center':'city mpg'}>],
#        [<AxesSubplot:title={'center':'Popularity'}>,
#         <AxesSubplot:title={'center':'MSRP'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# relationship between catagorical and continuos variable
sns.boxplot(x="Engine Cylinders", y="Engine HP",data=car)
# Out:
# <AxesSubplot:xlabel='Engine Cylinders', ylabel='Engine HP'>

# %%
# relationship between catagorical and continuos variable
sns.boxplot(x="Popularity", y="Engine HP",data=car)
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Engine HP'>

# %%
sns.boxplot(x="Year", y="Engine HP",data=car)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Engine HP'>

# %%
sns.boxplot(x="Year", y="Engine HP",data=car)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Engine HP'>

# %%
sns.boxplot(x="Engine Cylinders", y="Engine HP",data=car)
# Out:
# <AxesSubplot:xlabel='Engine Cylinders', ylabel='Engine HP'>

# %%
sns.boxplot( y="Engine HP",data=car)
# Out:
# <AxesSubplot:ylabel='Engine HP'>

# %%
# relationship between catagorical and continuos variable
sns.boxplot(x="Popularity", y="Engine HP",data=car)
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Engine HP'>

# %%
sns.pairplot(car)

# %%
#Drop irrelevant columns 
car =car.drop(['Engine Fuel Type','Engine HP','Engine Cylinders','Transmission Type','highway MPG','city mpg','MSRP'], axis =1)
car.head(5)
# Out:
#   Make       Model  Year     Driven_Wheels  Number of Doors  \
# 0  BMW  1 Series M  2011  rear wheel drive              2.0
# 1  BMW    1 Series  2011  rear wheel drive              2.0
# 2  BMW    1 Series  2011  rear wheel drive              2.0
# 3  BMW    1 Series  2011  rear wheel drive              2.0
# 4  BMW    1 Series  2011  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    Popularity
# 0        3916
# 1        3916
# 2        3916
# 3        3916
# 4        3916

# %%
car =car.rename(columns={"Engine Cylinders":"Cylinders","Transmission Type":"Transmission","highway MPG":"MPG-H","city mpg":"mpg-c","MSRP":"MM"})
car.head(5)
# Out:
#   Make       Model  Year     Driven_Wheels  Number of Doors  \
# 0  BMW  1 Series M  2011  rear wheel drive              2.0
# 1  BMW    1 Series  2011  rear wheel drive              2.0
# 2  BMW    1 Series  2011  rear wheel drive              2.0
# 3  BMW    1 Series  2011  rear wheel drive              2.0
# 4  BMW    1 Series  2011  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    Popularity
# 0        3916
# 1        3916
# 2        3916
# 3        3916
# 4        3916

# %%
car.shape
# Out:
# (11914, 9)

# %%
# rows cintaining duplicate data
duplicate_rows_car = car[car.duplicated()]
print("number of duplicate rows:",duplicate_rows_car.shape)
# Out:
# number of duplicate rows: (6906, 9)

# %%
#count the row before removing the data
car.count()
# Out:
# Make               11914
# Model              11914
# Year               11914
# Driven_Wheels      11914
# Number of Doors    11908
# Market Category     8172
# Vehicle Size       11914
# Vehicle Style      11914
# Popularity         11914
# dtype: int64

# %%
car= car.drop_duplicates()
car.head(5)
# Out:
#   Make       Model  Year     Driven_Wheels  Number of Doors  \
# 0  BMW  1 Series M  2011  rear wheel drive              2.0
# 1  BMW    1 Series  2011  rear wheel drive              2.0
# 2  BMW    1 Series  2011  rear wheel drive              2.0
# 3  BMW    1 Series  2011  rear wheel drive              2.0
# 4  BMW    1 Series  2011  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    Popularity
# 0        3916
# 1        3916
# 2        3916
# 3        3916
# 4        3916

# %%
car= car.drop_duplicates()
car.count()
# Out:
# Make               5008
# Model              5008
# Year               5008
# Driven_Wheels      5008
# Number of Doors    5004
# Market Category    3689
# Vehicle Size       5008
# Vehicle Style      5008
# Popularity         5008
# dtype: int64

# %%
#find the null values
print(car.isnull().sum())
# Out:
# Make               0
# Model              0
# Year               0
# Driven_Wheels      0
# Number of Doors    0
# Market Category    0
# Vehicle Size       0
# Vehicle Style      0
# Popularity         0
# dtype: int64

# %%
# drop the missing values
car=car.dropna()
car.count()
# Out:
# Make               3685
# Model              3685
# Year               3685
# Driven_Wheels      3685
# Number of Doors    3685
# Market Category    3685
# Vehicle Size       3685
# Vehicle Style      3685
# Popularity         3685
# dtype: int64

# %%
print(car.isnull().sum())
# Out:
# Make               0
# Model              0
# Year               0
# Driven_Wheels      0
# Number of Doors    0
# Market Category    0
# Vehicle Size       0
# Vehicle Style      0
# Popularity         0
# dtype: int64

# %%
sns.boxplot(x=car['Year'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# ploting a histogram for number of cars per brand
car.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
# ploting a histogram for number of cars per brand
car.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel("Number of cars")
plt.xlabel("Make");

# %%
#find relation between the variable
plt.figure(figsize=(20,10))
c =car.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                      Year  Number of Doors  Popularity
# Year             1.000000         0.197340    0.128161
# Number of Doors  0.197340         1.000000   -0.045005
# Popularity       0.128161        -0.045005    1.000000
